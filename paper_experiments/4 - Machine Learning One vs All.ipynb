# %% [markdown]
# # Machine Learning (One vs All)

# %% [markdown]
# ## Modules and functions

# %% [markdown]
# Import all the modules:

# %%
import pandas as pd

from xgboost import XGBClassifier

import matplotlib.pyplot as plt
# %matplotlib inline

plt.style.use("ggplot")

from notebooks import *

# %% [markdown]
# ## Loading

# %%
honey_badger_labels = load_dictionary("honey_badger_labels.pickle")

# %%
df_file_path = "dataset-filtered.csv"
df = pd.read_csv(df_file_path, low_memory=False)

# %%
print_dimensions(df)
# Out:
# The dataset has 158863 rows and 434 columns

# %% [markdown]
# ## Prepare data

# %%
addresses, X, y_binary, y_multi, scaler, feature_names = extract_experiment_data(df)
# Out:
# Scaled columns:
# contract_compiler_runs: [0, 330000000]
# contract_num_source_code_lines: [1, 11409]
# internal_transaction_count: [0, 1536860]
# normal_transaction_block_span: [0, 6415588]
# normal_transaction_count: [1, 10412943]
# normal_transaction_block_delta_mean: [0, 3693174]
# normal_transaction_block_delta_std: [0, 2248615]
# normal_transaction_count_per_block_mean: [1, 49]
# normal_transaction_count_per_block_std: [0, 74]
# normal_transaction_gas_mean: [23112, 8003887]
# normal_transaction_gas_std: [0, 3985463]
# normal_transaction_gas_used_mean: [21421, 7906343]
# normal_transaction_gas_used_std: [0, 3717662]
# normal_transaction_time_delta_mean: [0, 57482326]
# normal_transaction_time_delta_std: [0, 34437373]
# normal_transaction_value_mean: [0, 204365823294587692646400]
# normal_transaction_value_std: [0, 1285685747689323210211328]
#
# Extracted values:
# addresses (158863,)
# features (158863, 430)
# labels_binary (158863,)
# labels_multi (158863,)

# %%
for feature_name in feature_names:
    print(feature_name)
# Out:
# contract_compiler_runs
# contract_num_source_code_lines
# internal_transaction_count
# normal_transaction_block_span
# normal_transaction_count
# normal_transaction_block_delta_mean
# normal_transaction_block_delta_std
# normal_transaction_count_per_block_mean
# normal_transaction_count_per_block_std
# normal_transaction_gas_mean
# normal_transaction_gas_std
# normal_transaction_gas_used_mean
# normal_transaction_gas_used_std
# normal_transaction_time_delta_mean
# normal_transaction_time_delta_std
# normal_transaction_value_mean
# normal_transaction_value_std
# contract_has_library
# has_internal_transactions
# normal_transaction_before_creation_ratio
# normal_transaction_block_ratio
# normal_transaction_from_other_ratio
# normal_transaction_other_sender_ratio
# contract_compiler_minor_version_0
# contract_compiler_minor_version_1
# contract_compiler_minor_version_2
# contract_compiler_minor_version_3
# contract_compiler_patch_0
# contract_compiler_patch_1
# contract_compiler_patch_2
# contract_compiler_patch_3
# contract_compiler_patch_4
# contract_compiler_patch_5
# contract_compiler_patch_6
# contract_compiler_patch_7
# contract_compiler_patch_8
# contract_compiler_patch_9
# contract_compiler_patch_10
# contract_compiler_patch_11
# contract_compiler_patch_12
# contract_compiler_patch_13
# contract_compiler_patch_14
# contract_compiler_patch_15
# contract_compiler_patch_16
# contract_compiler_patch_17
# contract_compiler_patch_18
# contract_compiler_patch_19
# contract_compiler_patch_20
# contract_compiler_patch_21
# contract_compiler_patch_22
# contract_compiler_patch_23
# contract_compiler_patch_24
# contract_compiler_patch_25
# contract_compiler_patch_26
# contract_compiler_patch_27
# contract_compiler_patch_28
# contract_compiler_patch_29
# contract_compiler_patch_30
# contract_compiler_patch_31
# contract_compiler_patch_32
# contract_compiler_patch_33
# contract_compiler_patch_34
# contract_compiler_patch_35
# contract_compiler_patch_36
# contract_compiler_patch_37
# contract_compiler_patch_38
# contract_compiler_patch_39
# contract_compiler_patch_40
# contract_compiler_patch_41
# contract_compiler_patch_42
# contract_compiler_patch_43
# contract_compiler_patch_44
# contract_compiler_patch_45
# contract_compiler_patch_46
# contract_compiler_patch_47
# contract_compiler_patch_48
# contract_compiler_patch_49
# contract_compiler_patch_50
# contract_compiler_patch_51
# contract_compiler_patch_52
# contract_compiler_patch_53
# contract_compiler_patch_54
# contract_compiler_patch_55
# contract_compiler_patch_56
# contract_compiler_patch_57
# contract_compiler_patch_58
# contract_compiler_patch_59
# contract_compiler_patch_60
# contract_compiler_patch_61
# contract_compiler_patch_62
# contract_compiler_patch_63
# contract_compiler_patch_64
# contract_compiler_patch_65
# contract_compiler_patch_66
# contract_compiler_patch_67
# contract_compiler_patch_68
# contract_compiler_patch_69
# contract_compiler_patch_70
# contract_compiler_patch_71
# contract_compiler_patch_72
# contract_compiler_patch_73
# contract_compiler_patch_74
# contract_compiler_patch_75
# contract_compiler_patch_76
# contract_compiler_patch_77
# contract_compiler_patch_78
# contract_compiler_patch_79
# contract_compiler_patch_80
# contract_compiler_patch_81
# contract_compiler_patch_82
# contract_compiler_patch_83
# contract_compiler_patch_84
# contract_compiler_patch_85
# contract_compiler_patch_86
# contract_compiler_patch_87
# contract_compiler_patch_88
# contract_compiler_patch_89
# contract_compiler_patch_90
# contract_compiler_patch_91
# contract_compiler_patch_92
# contract_compiler_patch_93
# contract_compiler_patch_94
# contract_compiler_patch_95
# contract_compiler_patch_96
# contract_compiler_patch_97
# contract_compiler_patch_98
# contract_compiler_patch_99
# contract_compiler_patch_100
# contract_compiler_patch_101
# contract_compiler_patch_102
# contract_compiler_patch_103
# contract_compiler_patch_104
# contract_compiler_patch_105
# contract_compiler_patch_106
# contract_compiler_patch_107
# contract_compiler_patch_108
# contract_compiler_patch_109
# contract_compiler_patch_110
# contract_compiler_patch_111
# contract_compiler_patch_112
# contract_compiler_patch_113
# contract_compiler_patch_114
# contract_compiler_patch_115
# contract_compiler_patch_116
# contract_compiler_patch_117
# contract_compiler_patch_118
# contract_compiler_patch_119
# contract_compiler_patch_120
# contract_compiler_patch_121
# contract_compiler_patch_122
# contract_compiler_patch_123
# contract_compiler_patch_124
# contract_compiler_patch_125
# contract_compiler_patch_126
# contract_compiler_patch_127
# contract_compiler_patch_128
# contract_compiler_patch_129
# contract_compiler_patch_130
# contract_compiler_patch_131
# contract_compiler_patch_132
# contract_compiler_patch_133
# contract_compiler_patch_134
# contract_compiler_patch_135
# contract_compiler_patch_136
# contract_compiler_patch_137
# contract_compiler_patch_138
# contract_compiler_patch_139
# contract_compiler_patch_140
# contract_compiler_patch_141
# contract_compiler_patch_142
# contract_compiler_patch_143
# contract_compiler_patch_144
# contract_compiler_patch_145
# contract_compiler_patch_146
# contract_compiler_patch_147
# contract_compiler_patch_148
# contract_compiler_patch_149
# contract_compiler_patch_150
# contract_compiler_patch_151
# contract_compiler_patch_152
# contract_compiler_patch_153
# contract_compiler_patch_154
# contract_compiler_patch_155
# contract_compiler_patch_156
# contract_compiler_patch_157
# contract_compiler_patch_158
# contract_compiler_patch_159
# contract_compiler_patch_160
# contract_compiler_patch_161
# contract_compiler_patch_162
# contract_compiler_patch_163
# contract_compiler_patch_164
# contract_compiler_patch_165
# contract_compiler_patch_166
# contract_compiler_patch_167
# contract_compiler_patch_168
# contract_compiler_patch_169
# contract_compiler_patch_170
# contract_compiler_patch_171
# contract_compiler_patch_172
# contract_compiler_patch_173
# contract_compiler_patch_174
# contract_compiler_patch_175
# contract_compiler_patch_176
# contract_compiler_patch_177
# contract_compiler_patch_178
# contract_compiler_patch_179
# contract_compiler_patch_180
# contract_compiler_patch_181
# contract_compiler_patch_182
# contract_compiler_patch_183
# contract_compiler_patch_184
# contract_compiler_patch_185
# contract_compiler_patch_186
# contract_compiler_patch_187
# contract_compiler_patch_188
# contract_compiler_patch_189
# contract_compiler_patch_190
# contract_compiler_patch_191
# contract_compiler_patch_192
# contract_compiler_patch_193
# contract_compiler_patch_194
# contract_compiler_patch_195
# contract_compiler_patch_196
# contract_compiler_patch_197
# contract_compiler_patch_198
# contract_compiler_patch_199
# contract_compiler_patch_200
# contract_compiler_patch_201
# contract_compiler_patch_202
# contract_compiler_patch_203
# contract_compiler_patch_204
# contract_compiler_patch_205
# contract_compiler_patch_206
# contract_compiler_patch_207
# contract_compiler_patch_208
# contract_compiler_patch_209
# contract_compiler_patch_210
# contract_compiler_patch_211
# contract_compiler_patch_212
# contract_compiler_patch_213
# contract_compiler_patch_214
# contract_compiler_patch_215
# contract_compiler_patch_216
# contract_compiler_patch_217
# contract_compiler_patch_218
# contract_compiler_patch_219
# contract_compiler_patch_220
# contract_compiler_patch_221
# contract_compiler_patch_222
# contract_compiler_patch_223
# contract_compiler_patch_224
# contract_compiler_patch_225
# contract_compiler_patch_226
# contract_compiler_patch_227
# contract_compiler_patch_228
# contract_compiler_patch_229
# contract_compiler_patch_230
# contract_compiler_patch_231
# contract_compiler_patch_232
# contract_compiler_patch_233
# contract_compiler_patch_234
# contract_compiler_patch_235
# contract_compiler_patch_236
# contract_compiler_patch_237
# contract_compiler_patch_238
# contract_compiler_patch_239
# contract_compiler_patch_240
# contract_compiler_patch_241
# contract_compiler_patch_242
# contract_compiler_patch_243
# contract_compiler_patch_244
# contract_compiler_patch_245
# contract_compiler_patch_246
# contract_compiler_patch_247
# contract_compiler_patch_248
# contract_compiler_patch_249
# contract_compiler_patch_250
# contract_compiler_patch_251
# contract_compiler_patch_252
# contract_compiler_patch_253
# contract_compiler_patch_254
# contract_compiler_patch_255
# contract_compiler_patch_256
# contract_compiler_patch_257
# contract_compiler_patch_258
# contract_compiler_patch_259
# contract_compiler_patch_260
# contract_compiler_patch_261
# contract_compiler_patch_262
# contract_compiler_patch_263
# contract_compiler_patch_264
# contract_compiler_patch_265
# contract_compiler_patch_266
# contract_compiler_patch_267
# contract_compiler_patch_268
# contract_compiler_patch_269
# contract_compiler_patch_270
# contract_compiler_patch_271
# contract_compiler_patch_272
# contract_compiler_patch_273
# contract_compiler_patch_274
# contract_compiler_patch_275
# contract_compiler_patch_276
# contract_compiler_patch_277
# contract_compiler_patch_278
# contract_compiler_patch_279
# contract_compiler_patch_280
# contract_compiler_patch_281
# contract_compiler_patch_282
# contract_compiler_patch_283
# contract_compiler_patch_284
# contract_compiler_patch_285
# contract_compiler_patch_286
# contract_compiler_patch_287
# contract_compiler_patch_288
# contract_compiler_patch_289
# contract_compiler_patch_290
# contract_compiler_patch_291
# contract_compiler_patch_292
# contract_compiler_patch_293
# contract_compiler_patch_294
# contract_compiler_patch_295
# contract_compiler_patch_296
# contract_compiler_patch_297
# contract_compiler_patch_298
# contract_compiler_patch_299
# contract_compiler_patch_300
# contract_compiler_patch_301
# contract_compiler_patch_302
# contract_compiler_patch_303
# contract_compiler_patch_304
# contract_compiler_patch_305
# contract_compiler_patch_306
# contract_compiler_patch_307
# contract_compiler_patch_308
# contract_compiler_patch_309
# contract_compiler_patch_310
# contract_compiler_patch_311
# contract_compiler_patch_312
# contract_compiler_patch_313
# contract_compiler_patch_314
# contract_compiler_patch_315
# contract_compiler_patch_316
# contract_compiler_patch_317
# contract_compiler_patch_318
# contract_compiler_patch_319
# contract_compiler_patch_320
# contract_compiler_patch_321
# contract_compiler_patch_322
# contract_compiler_patch_323
# contract_compiler_patch_324
# contract_compiler_patch_325
# contract_compiler_patch_326
# contract_compiler_patch_327
# contract_compiler_patch_328
# contract_compiler_patch_329
# symbol_22
# symbol_33
# symbol_39
# symbol_41
# symbol_43
# symbol_49
# symbol_51
# symbol_53
# symbol_54
# symbol_55
# symbol_57
# symbol_59
# symbol_61
# symbol_62
# symbol_63
# symbol_65
# symbol_66
# symbol_67
# symbol_69
# symbol_71
# symbol_73
# symbol_75
# symbol_76
# symbol_77
# symbol_78
# symbol_79
# symbol_81
# symbol_82
# symbol_83
# symbol_85
# symbol_86
# symbol_87
# symbol_93
# symbol_95
# symbol_103
# symbol_105
# symbol_113
# symbol_121
# symbol_122
# symbol_123
# symbol_127
# symbol_129
# symbol_133
# symbol_135
# symbol_137
# symbol_171
# symbol_173
# symbol_177
# symbol_179
# symbol_181
# symbol_183
# symbol_185
# symbol_187
# symbol_189
# symbol_191
# symbol_193
# symbol_194
# symbol_195
# symbol_197
# symbol_198
# symbol_199
# symbol_201
# symbol_202
# symbol_203
# symbol_204
# symbol_205
# symbol_207
# symbol_208
# symbol_209
# symbol_211
# symbol_213
# symbol_214
# symbol_215

# %% [markdown]
# ## Classification

# %%
xgb_scale_pos_weight = compute_scale_pos_weight(y_binary)

# %%
def create_xgb_model():
    return XGBClassifier(n_jobs=10,
                         scale_pos_weight=xgb_scale_pos_weight,
                         n_estimators=25,
                         max_depth=3)

# %%
num_labels = len(honey_badger_labels["index_to_name"])

for label_id, label_value in enumerate(honey_badger_labels["index_to_name"][1:], start=1):
    print("Label {:d}/{:d} = {}".format(label_id, num_labels, label_value))

    train_index = y_multi != label_id
    test_index = y_multi == label_id
    
    xgb_model = create_xgb_model()
    xgb_model.fit(X[train_index], y_binary[train_index])
    
    train_metrics = compute_metrics(y_binary[train_index], xgb_model.predict(X[train_index]))
    print_metrics("train", train_metrics)
    
    test_pred = xgb_model.predict(X[test_index])
    test_size = test_pred.shape[0]
    test_tp = test_pred.sum()
    test_fp = test_size - test_tp
    test_acc = test_tp / test_size
    print("test  Recall {:.03f} FN {:d} TP {:d}".format(test_acc, test_fp, test_tp))
    print()
# Out:
# Label 1/9 = Balance Disorder
# train ROC AUC 0.981 TN  156456 FP  2112 FN     7 TP   268
# test  Recall 0.850 FN 3 TP 17
#
# Label 2/9 = Hidden State Update
# train ROC AUC 0.984 TN  157575 FP   993 FN     4 TP   156
# test  Recall 0.911 FN 12 TP 123
#
# Label 3/9 = Hidden Transfer
# train ROC AUC 0.982 TN  156654 FP  1914 FN     7 TP   275
# test  Recall 0.923 FN 1 TP 12
#
# Label 4/9 = Inheritance Disorder
# train ROC AUC 0.985 TN  156804 FP  1764 FN     5 TP   247
# test  Recall 0.884 FN 5 TP 38
#
# Label 5/9 = Skip Empty String Literal
# train ROC AUC 0.987 TN  156206 FP  2362 FN     3 TP   282
# test  Recall 0.900 FN 1 TP 9
#
# Label 6/9 = Straw Man Contract
# train ROC AUC 0.984 TN  156479 FP  2089 FN     5 TP   259
# test  Recall 0.903 FN 3 TP 28
#
# Label 7/9 = Type Deduction Overflow
# train ROC AUC 0.984 TN  156607 FP  1961 FN     6 TP   285
# test  Recall 1.000 FN 0 TP 4
#
# Label 8/9 = Uninitialised Struct
# train ROC AUC 0.988 TN  156687 FP  1881 FN     3 TP   253
# test  Recall 0.949 FN 2 TP 37
